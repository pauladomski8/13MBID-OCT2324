# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### AP2 - Visualización de los datos
#
# ---
#
# En esta libreta se generan los modelos de visualización (gráficos) sobre los datasets
# del escenario para su posterior integración en la herramienta a utilizar.
#
# ---

# %%
# Importación de librerías

import pandas as pd
# En esta línea se podría producir un error, se debe instalar plotly
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ----
#
# ##### Lectura del dataset

# %%
df = pd.read_csv("../../../data/final/datos_finales.csv", sep=";")
df.head(5)
# Out:
#   estado_civil_N estado_credito_N operaciones_ult_12m gastos_ult_12m  \
# 0              C                P           mayor_100      mayor_10k
# 1              S                C             15_a_30       menor_1k
# 2              D                P             15_a_30        2k_a_4k
# 3              S                P            75_a_100        2k_a_4k
# 4              C                P             50_a_75        4k_a_6k
#
#   limite_credito_tc antiguedad_cliente tasa_interes    ingresos pct_ingreso  \
# 0           3k_a_5k            2y_a_4y     hasta_7p  50k_a_100k    hasta_20
# 1           3k_a_5k            2y_a_4y    15p_a_20p   20k_a_50k    hasta_20
# 2          5k_a_10k            2y_a_4y     7p_a_15p   20k_a_50k     20_a_40
# 3          menor_3k           menor_2y     7p_a_15p   20k_a_50k     20_a_40
# 4           3k_a_5k            2y_a_4y     7p_a_15p  50k_a_100k     20_a_40
#
#   antiguedad_empleado      edad  importe_solicitado  duracion_credito  \
# 0              5_a_10  menor_25               11000                 3
# 1             menor_5  menor_25                1500                 2
# 2              5_a_10  menor_25               10000                 2
# 3             menor_5   25_a_30                6000                 4
# 4             menor_5   25_a_30               10000                 2
#
#   situacion_vivienda objetivo_credito falta_pago estado_cliente genero  \
# 0           HIPOTECA      INVERSIONES          N         ACTIVO      F
# 1           ALQUILER    MEJORAS_HOGAR          Y         PASIVO      M
# 2              OTROS        EDUCACIÓN          Y         PASIVO      M
# 3           ALQUILER      INVERSIONES          N         ACTIVO      F
# 4           HIPOTECA        EDUCACIÓN          N         ACTIVO      F
#
#             nivel_educativo  personas_a_cargo
# 0       SECUNDARIO_COMPLETO               3.0
# 1               DESCONOCIDO               0.0
# 2         POSGRADO_COMPLETO               3.0
# 3  UNIVERSITARIO_INCOMPLETO               2.0
# 4  UNIVERSITARIO_INCOMPLETO               2.0

# %% [markdown]
# ----
#
# ##### Definición de gráficos de interés

# %%
# Cantidad de créditos por objetivo del mismo

creditos_x_objetivo = px.histogram(df, x='objetivo_credito', 
                                   title='Conteo de créditos por objetivo')
creditos_x_objetivo.update_layout(xaxis_title='Objetivo del crédito', yaxis_title='Cantidad')

# %%
# Histograma de los importes de créditos otorgados

histograma_importes = px.histogram(df, x='importe_solicitado', nbins=10, title='Importes solicitados en créditos')
histograma_importes.update_layout(xaxis_title='Importe solicitado', yaxis_title='Cantidad')

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['limite_credito_tc'])]['limite_credito_tc']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'limite_credito_tc Value Counts'},
    'xaxis': {'title': {'text': 'limite_credito_tc'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
# from plotly.offline import iplot, init_notebook_mode
#
# init_notebook_mode(connected=True)
# for chart in charts:
#     chart.pop('id', None) # for some reason iplot does not like 'id'
# iplot(figure)
figure
# Out:
# C:\Users\Paula Domski\AppData\Local\Temp\ipykernel_13016\1740162360.py:15: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['falta_pago'])]['falta_pago']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'falta_pago Value Counts'},
    'xaxis': {'title': {'text': 'falta_pago'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
# from plotly.offline import iplot, init_notebook_mode
#
# init_notebook_mode(connected=True)
# for chart in charts:
#     chart.pop('id', None) # for some reason iplot does not like 'id'
# iplot(figure)
figure
# Out:
# C:\Users\Paula Domski\AppData\Local\Temp\ipykernel_23532\3604861786.py:11: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   chart = pd.value_counts(s).to_frame(name='data')

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'


if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['situacion_vivienda'])]['situacion_vivienda']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'situacion_vivienda Value Counts'},
    'xaxis': {'title': {'text': 'situacion_vivienda'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


figure
# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
# from plotly.offline import iplot, init_notebook_mode
#
# init_notebook_mode(connected=True)
# for chart in charts:
#     chart.pop('id', None) # for some reason iplot does not like 'id'
# iplot(figure)
# Out:
# C:\Users\Paula Domski\AppData\Local\Temp\ipykernel_23532\3308307528.py:12: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'


if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['pct_ingreso'])]['pct_ingreso']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
ordinal_data = df.groupby('pct_ingreso')[['importe_solicitado']].sum()
chart['ordinal'] = ordinal_data
chart.index.name = 'labels'
chart = chart.reset_index().sort_values('ordinal')
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
charts.append(go.Scatter(
	x=chart['labels'].values, y=chart['ordinal'].values, yaxis='y2',
	name='importe_solicitado (sum)', line={'shape': 'spline', 'smoothing': 0.3}, mode='lines'
))
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'pct_ingreso Value Counts'},
    'xaxis': {'title': {'text': 'pct_ingreso'}},
    'yaxis': {'title': {'text': 'Frequency'}},
    'yaxis2': {'overlaying': 'y', 'side': 'right', 'title': {'text': 'importe_solicitado (sum)'}}
}))


figure
# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
# from plotly.offline import iplot, init_notebook_mode
#
# init_notebook_mode(connected=True)
# for chart in charts:
#     chart.pop('id', None) # for some reason iplot does not like 'id'
# iplot(figure)
# Out:
# C:\Users\Paula Domski\AppData\Local\Temp\ipykernel_23532\16881029.py:12: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %%
# Conteo de ocurrencias por estado
estado_credito_counts = df['estado_credito_N'].value_counts()

# Gráfico de torta de estos valores
fig = go.Figure(data=[go.Pie(labels=estado_credito_counts.index, values=estado_credito_counts)])
fig.update_layout(title_text='Distribución de créditos por estado registrado')
fig.show()

# %%
# Conteo de ocurrencias por caso
falta_pago_counts = df['falta_pago'].value_counts()

# Create a Pie chart
fig = go.Figure(data=[go.Pie(labels=falta_pago_counts.index, values=falta_pago_counts)])
fig.update_layout(title_text='Distribución de créditos en función de registro de mora')
fig.show()
